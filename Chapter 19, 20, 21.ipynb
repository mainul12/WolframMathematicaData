# %%
Histogram[Table[Mean[RandomVariate[DiscreteUniformDistribution[{1, 7}], 50]], 1000]]
# Out:
# -Graphics-

# %%
Histogram[Table[Mean[RandomVariate[DiscreteUniformDistribution[{1, 7}], 50]], 1000]]
# Out:
# -Graphics-

# %%
FindDistribution[Table[Mean[RandomVariate[DiscreteUniformDistribution[{1, 7}], 50]], 1000]]
# Out:
# NormalDistribution[3.99391, 0.314288]

# %%
Histogram[Table[Mean[RandomVariate[DiscreteUniformDistribution[{1, 7}], 200]], 1000]]
# Out:
# -Graphics-

# %%
Histogram[Table[Mean[RandomVariate[DiscreteUniformDistribution[{3, 5}], 200]], 1000]]
# Out:
# -Graphics-

# %% [markdown]
# ## Chapter 22 R code
# `hist(replicate(1000, mean(replicate(100, qnorm(RAND(), 4, 1)))))`
#
# brush up knowledge of qnorm
